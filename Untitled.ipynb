# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.models as models

from torchTransformer import TorchTransformer
from quantize import QConv2d

# %%
model = models.__dict__["resnet18"]()

# %%
transofrmer = TorchTransformer()

# %%
dot = transofrmer.visualize(model)

# %%
dot
# Out:
# ----------------------------------------------------------------------
# FileNotFoundError                    Traceback (most recent call last)
# ~/anaconda3/envs/py36/lib/python3.6/site-packages/graphviz/backend.py in run(cmd, input, capture_output, check, quiet, **kwargs)
#     157     try:
# --> 158         proc = subprocess.Popen(cmd, startupinfo=get_startupinfo(), **kwargs)
#     159     except OSError as e:
#
# ~/anaconda3/envs/py36/lib/python3.6/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors)
#     728                                 errread, errwrite,
# --> 729                                 restore_signals, start_new_session)
#     730         except:
#
# ...
